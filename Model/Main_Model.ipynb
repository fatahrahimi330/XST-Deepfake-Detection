# %% [markdown]
# <a href="https://colab.research.google.com/github/fatahrahimi330/XST-Deepfake-Detection/blob/master/Model/Main_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Model CNN+ViT+BiLSTM

# %% [markdown]
# ## 1. Importing Libraries

# %% [markdown]
# ## 2. Loading Dataset

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ## 4. Build the Model

# %% [markdown]
# ## 5. Compile and Fit the Model

# %% [markdown]
# ## 6. Make Prediction

# %% [markdown]
# ## 7. Evaluate the Model

# %% [markdown]
# ## 8. Save the Model
