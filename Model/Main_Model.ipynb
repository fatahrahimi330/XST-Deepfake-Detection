# %% [markdown]
# <a href="https://colab.research.google.com/github/fatahrahimi330/XST-Deepfake-Detection/blob/master/Model/Main_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Model CNN+ViT+BiLSTM

# %% [markdown]
# ## 1. Importing Libraries

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import timm

# %% [markdown]
# ## 2. FFPP Dataset

# %%
class FFPPDataset(Dataset):

  def __init__(self, data_dir, transform=None):
    self.data = ImageFolder(data_dir, transform=transform)

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    return self.data[idx]

  @property
  def classes(self):
    return self.data.classes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = FFPPDataset(data_dir= '/content/drive/MyDrive/XST-Deepfake-Detection/processed_ffpp')

# %%
len(dataset)
# Out:
# 31223

# %%
dataset[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=224x224>, 0)

# %%
image, label = dataset[500]
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
label
# Out:
# 0

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# %% [markdown]
# ## 3. Loading Dataset

# %%
data_dir = '/content/drive/MyDrive/XST-Deepfake-Detection/processed_ffpp/train'

dataset = FFPPDataset(data_dir, transform)

# %%
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
for images, labels in data_loader:
  break

# %%
images.shape, labels.shape
# Out:
# (torch.Size([32, 3, 128, 128]), torch.Size([32]))

# %% [markdown]
# ## 4. Build the Model

# %% [markdown]
# ## 5. Loop and Fit the Model

# %% [markdown]
# ## 6. Make Prediction

# %% [markdown]
# ## 7. Evaluate the Model

# %% [markdown]
# ## 8. Save the Model
